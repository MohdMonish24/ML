# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Linear Regression 5 * - Mohd Monish</p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Q1. What is Linear Regression?⭐
# Q2. What is the differentce between Simple linear regression and multiple linear regression?⭐
# Q3. What is the difference between the loss function and cost function? ⭐
# Q4. What Are The Basic Assumption? (Favourite) ⭐
# Q5. How can you calculate error in linear regression?
# Q6. How do you evaluate the performance of a linear regression model?
# Q7. Different Between MSE, MAE & RMSE? ⭐
# Q8. What is R -squared and adjusted R -square? ⭐
# Q9. Difference between R-square and Adjusted R-square?⭐
# Q10. Explain how Gradient descent work in Linear Regression?⭐
# Q11. Explain what the intercept term means?
# Q12. How is hypothesis testing used in linear regression?
# Q13. How would you decide the importance of variables for the multivariate regression?
# Q14. How do you interpret the coefficient of a linear regression model?
# Q15. What is the purpose of the residual plot in linear regression?
# Q16. How do you handle multicollinearity in linear regression?
# Q17.  What are the assumptions of the error term in linear regression?
# Q18. What are some techniques to improve the performance of a linear regression model?

# %% [markdown]
# # Q1. What is Linear Regression?
#
# • Linear Regression is a most Popular SUPERVISED & PARAMETRIC Machine Learnig Algorithems.
#
# • It is astatistical technique, which is used to model the relationship between a dependent variable and one or more independent variables.
#
# • It assumes a linear relationship between the variables, meaning that the dependent variable can be represented as a linaer combination of the independent variables, plusan error term.
#
# • The goal of linear regression is to find the best-fitting line, known as the regression line, that minimizes the differences(sum of squared errors) between the Predicted values and Actual values of the dependent variable.
#
# The equation of a simple linear regression model can be represented as: y = mx + c
#
# Where:
#
# y is the dependent variable (target variable)
#
# x is the independent variable (input variable)
#
# m is the slope of the line (coefficient)
#
# c is the y-intercept (constant term)

# %% [markdown]
# # Q2. What is the differentce between Simple linear regression and multiple linear regression?
#
# Simple linear regression is a type of linear regression where the target variable is predicted using a single predictor variable. The relationship between the predictor variable and the target variable is represented by a straight line.
#
# The equation for a simple linear regression model is:  y = b0 + b1*x
#
# where
#
# y is the dependent(target) variable,
#
# x is the independent(predictor) variable,
#
# bO is the y-intercept, and b1 is the slope of the line/coefficient.
#
#
# Multiple linear regression, on the other hand, is a type of linear regression where the target variable is predicted using multiple predictor variables. The relationship between the predictor variables and the target variable is represented by a hyperplane.
#
# The equation for a multiple linear regression model is: y = b0 + b1_x1 + b2_x2 + ... + bn*xn
#
# Where
#
# y is the dependent(target) variable,
#
# x1,x2,...,xn are the independent(predictor) variables,
#
# bO is the y-intercept, and b1, b2,...bn  are the coefficients or slopesof the predictor variables.

# %% [markdown]
# # How do you decide which one to use for a given problem?.
#
# When deciding which type of linear regression to use, you should consider the number of predictor variables and the relationship between the predictor variables and the target variable. If there is only one predictor variable and the relationship between the predictor variable and the target variable is approximately linear, then simple linear regression is a good choice. If there are multiple predictor variables and the relationship between the predictor variables and the target variable is approximately linear, then multiple linear regression is a good choice.

# %% [markdown]
# # Q3. What is the difference between the loss function and cost function?
#
# The loss function is used to capture the error or the difference between the Actual(real) value and Predicted(observed) value for a single record.
#
# whereas the cost function determines (aggeregate) the difference for the entire training dataset.

# %% [markdown]
# # Q4. What Are The Basic Assumption? (Favourite)10⭐
#
# There are four assumptions associated with a linear regression model:
#
# 1. Linearity: The relationship between the predictor variables and the target variable is linear. This means that a straight line can be used to approximate the relationship.
#
# 2. Independence of errors/Autocorrelation: The errors (residuals) of the model are independent and identically distributed. This means that the errors are not correlated and have the same distribution.
#
# 3. Homoscedasticity: The variance of the errors is constant across all levels of the predictor variables. This means that the spread of the errors is the same for all levels of the predictor variables.
#
# 4. Normality: The errors are normally distributed. This means that the distribution of the errors follows a normal (or Gaussian) distribution.
#
# 5. No Multicolinearity: The predictor variables are not highly correlated with each other. This means that the predictor variables are independent of each other.

# %% [markdown]
# # Q5. How can you calculate error in linear regression?
#
# We Can Calculate the error in Linear Regression by various methods. Some are the
# Followings:-
#
# 1. Mean Square Error(MSE)
# 2. Mean Absolute Error(MAE)
# 3. Root Mean Square Error(RMSE)

# %% [markdown]
# # Q6. How do you evaluate the performance of a linear regression model?
#
# Common evaluation metrics for linear regression include R- squared, adjusted R-squared, mean squared error (MSE), root mean squared error (RMSE), and
# mean absolute error (MAE).

# %% [markdown]
# # Q7. Different Between MSE, MAE & RMSE?

# %% [markdown]
# # 1. Mean Squared Error (MSE)
#
# IT is a widely used metric in regression problems to measure the average squared difference between the predicted values and the actual values. It provides a measure of how well a regression model fits the data points.
#
# Mathematically, MSE is calculated by taking the average of the squared differences between the predicted values (ŷ) and the actual values (y):
#
# ![image.png](attachment:image.png)
# Where:
#
# n is the total number of data
#
# y represents the actual values of the dependent variable
#
# ŷ represents the predicted values of the dependent variable
#
# Few Important points Related to MSE
#
# - It’s differentiable, so it can be optimized better.
#
# - Calculates the average squared difference between predicted and actual values.
#
# - Emphasizes larger errors due to the squaring operation.
#
# - Useful when larger errors need to be penalized more heavily.
#
# - Sensitive to outliers and can be influenced by extreme values.
#
#
# Advantage.
#
# - The equation is differentiable.
# - It has only one local and globel minima.
#
# Disadvantage
#
# - Not Robust to outlier.

# %% [markdown]
# # 2. Mean Absolute Error
#
# MAE (Mean Absolute Error) is another commonly used metric for evaluating the performance of regression models. It measures the average absolute difference between the predicted values and the actual values of the dependent variable. Unlike RMSE, MAE does not involve squaring the differences, making it less sensitive to outliers.
#
# The MAE is calculated by taking the average of the absolute differences between the predicted values (ŷ) and the actual values (y) of the dependent variable. The formula for MAE is as follows:
#
# ![image.png](attachment:image.png)
#
#
# n represents the total number of data points,
#
# y represents the actual values of the dependent variable,
#
# ŷ represents the predicted values of the dependent variable.
#
# Few Important points Related to MAE
#
# - Gives equal weight to all errors regardless of their magnitude.
#
# - Less sensitive to outliers compared to MSE.
#
# - Provides a more robust measure of prediction accuracy.
#
# - Easier to interpret since it is in the same unit as the target variable.
#
# - It is useful if the training data has outliers as MAE does not penalize high errors caused by outliers.
#
# - MAE is non-differentiable as opposed to MSE, which is differentiable.
#
# - It can be challenging to compute gradients in MAE.
#
#
# Advantage
#
# - Robust to outlier
#
# Disadvantage
#
# - Convergence usually takes more time.

# %% [markdown]
# # 3. Root Means Square
#
# RMSE (Root Mean Squared Error) is commonly used as a performance metric in regression problems, especially when the scale of the dependent variable is significant.
#
# The RMSE is calculated by taking the square root of the average of the squared differences between the predicted values (ŷ) and the actual values (y) of the dependent variable. The formula for RMSE is as follows:
#
# ![image.png](attachment:image.png)
#
# n is the total number of data points
#
# y represents the actual values of the dependent variable
#
# ŷ represents the predicted values of the dependent variable
#
# Few Important points Related to RMSE
#
# - It retains the differentiable property of MSE.
#
# - Similar to MSE but with the added advantage of being in the same unit as the target variable.
#
# - It handles the larger errors due to the square root operation done by MSE by square rooting it.
#
# - RMSE does not penalize the errors as much as MSE does due to the square root.
#
# - Provides a more intuitive and interpretable measure of prediction accuracy compared to MSE.
#
# - Preserves the same unit as the target variable, making it easier to compare and understand the magnitude of the errors.
#
# - MSE values are expressed in quadratic equations. Hence when we plot it, we get a gradient descent with only one global minima.

# %% [markdown]
# # Q8. Can you explain the bias-variance tradeoff?.10⭐
#
# The bias-variance tradeoff is a fundamental concept in machine learning that describes the trade-off between how well a model fits the training data (bias) and how well the model generalizes to new, unseen data (variance).
#
# Bias refers to the error introduced by approximating a real-world problem, which may be incredibly complex, with a much simpler model. High-bias models are typically considered to be "oversimplified" and will have a high error on the training set.
#
# On the other hand, variance refers to the error introduced by the model's sensitivity to small fluctuations in the training data. High variance models are typically considered to be "overcomplicated" or "overfit" and will have a higer  erroe on the test data.
# ![image.png](attachment:image.png)

# %% [markdown]
# # Q9. What is R -squared and adjusted R -square? 10⭐

# %% [markdown]
# # 🔘 R² -Coefficient of determination
#
# The R² score, also known as the coefficient of determination or goodness of fit, is a metric in machine learning that measures how well a regression model fits the data
#
# A higher R² score indicates a better fit, and it allows us to compare the model’s performance against a baseline model that uses the mean value of the target variable.
#
# If the R² score is zero, it means that the regression line is equivalent to the mean line. In this case, both lines overlap, indicating that the model’s performance is poor and it fails to capture any meaningful relationship in the data.
#
# If the R² score is one, it implies that the regression line perfectly fits the data without any errors. However, achieving a perfect R² score is highly unlikely in real-world scenarios.
#
# In general cases, the R² score falls between zero and one, such as 0.8. This indicates that the model can explain 80 percent of the variance in the data. As the R² score approaches one, the regression line gets closer to perfection, indicating an improvement in model performance.
#
# Few Important points Related to R²
#
# - R²is a measure of how well a regression model fits the data and explains the variability in the dependent variable.
#
# - It ranges between 0 and 1, with 0 indicating no variability explained and 1 indicating a perfect fit.
#
# - R² can be used to compare different models, with higher values indicating better performance.
#
# - However, R²should be interpreted with caution as it doesn’t provide information on statistical significance or causality.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 🔘 Adjusted R2  or Adjusted R-Squared
#
# Adjusted R-squared is a modified version of R-squared that has been adjusted for the
# number of predictors in the model. The adjusted R-squared increases when the new term
# improves the model more than would be expected by chance. It decreases when a
# predictor improves the model by less than expected. Typically, the adjusted R-squared is
# positive, not negative. It is always lower than the R-squared
#
# ![image.png](attachment:image.png)
#
# Few Important points Related to R²
#
# - Adjusted R² is a modified version of the R² (R-squared) score that adjusts for the number of features in a regression model.
#
# - Unlike R², which tends to increase as more features are added, Adjusted R² penalizes the inclusion of unnecessary features that do not contribute significantly to the model’s predictive power.
#
# - Adjusted R² provides a more reliable measure of model performance by accounting for the trade-off between model complexity and goodness of fit.
#
# - It is particularly useful when comparing regression models with different numbers of features, as it helps identify the model that strikes the right balance between simplicity and predictive power.
#
# - The Adjusted R² score ranges from negative infinity to 1, with a higher score indicating a better fit and a greater proportion of variance explained by the independent variables.
#
# - Negative values of Adjusted R² may occur when the model performs worse than a simple average or when the number of features is excessively large compared to the sample size.

# %% [markdown]
# # Q. Difference between R-square and Adjusted R-square?
#
# Every time you add a independent variable to a model, the R-squared increases, even if the independent variable is insignificant. It never declines. Whereas Adjusted R-squared increases only when independent variable is significant and affects dependent variable.
#
# In the table below, adjusted r-squared is maximum when we included two variables. It declines when third variable is added. Whereas r-squared increases when we included third variable. It means third variable is insignificant to the model. R-Squared vs. Adjusted R-Squared Adjusted r-squared can be negative when r-squared is close to zero. Adjusted r-squared value always be less than or equal to r-squared value.
#
#                                            or
#
# R-squared measures the proportion of variance in the dependent variable explained by the independent variables,
#
# while adjusted R-squared adjusts for the number of predictors in the model

# %% [markdown]
# # 🔘 Which is better?
#
# Adjusted R-square should be used to compare models with different numbers of independent variables. Adjusted R-square should be used while selecting important predictors (independent variables) for the regression model.

# %% [markdown]
# # Q10. Explain how Gradient descent work in Linear Regression?
#
# Gradient Descent is an algorithm that finds the best-fit line for a given training dataset in a
# smaller number of iterations.
#
#
# If we plot m and c against MSE, it will acquire a bowl shape (As shown in the diagram below)
# For some combination of m and c, we will get the least Error (MSE). That combination of m
# and c will give us our best fit line.
#
# ![image.png](attachment:image.png)
#
# The algorithm starts with some value of m and c (usually starts with m=0, c=0). We calculate
# MSE (cost) at point m=0, c=0. Let say the MSE (cost) at m=0, c=0 is 100. Then we reduce the
# value of m and c by some amount (Learning Step). We will notice a decrease in MSE (cost).
# We will continue doing the same until our loss function is a very small value or ideally 0
# (which means 0 error or 100% accuracy)
#
# Step-by-Step Algorithm:
#
# 1. Let m = 0 and c = 0. Let L be our learning rate. It could be a small value like 0.01 for good
# accuracy.
#
# The learning rate gives the rate of speed where the gradient moves during gradient descent.
# Setting it too high would make your path unstable, and too low would make convergence
# slow. Put it to zero means your model isn’t learning anything from the gradients.
#
# 2. Calculate the partial derivative of the Cost function with respect to m. Let the partial  derivative of the Cost function with respect to m be Dm (With little change in m how much  the Cost function changes).
#
# ![image-2.png](attachment:image-2.png)
#
# Similarly, let’s find the partial derivative with respect to c. Let the partial derivative of the
# Cost function with respect to c be Dc (With little change in c how much the Cost function
# changes)
#
# ![image-3.png](attachment:image-3.png)
#
# 3. Now update the current values of m and c using the following equation:
# ![image-4.png](attachment:image-4.png)
#
# 4. We will repeat this process until our Cost function is very small (ideally 0).
# The gradient Descent Algorithm gives optimum values of m and c of the linear regression
# equation. With these values of m and c, we will get the equation of the best-fit line and be
# ready to make predictions.

# %% [markdown]
# # Q11. Explain what the intercept term means?
#
#
# In the best fit-line when x=0 where the line meet the  Y-Axis that is called Intercept(c).
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Q12. How is hypothesis testing used in linear regression?
#
# Hypothesis testing is used to Confirm if beta coefficients are significant in a linear regression model.
# Every Time  we run the liner regression Model, we test if the significant or not by checking coefficient is significant
#
# ![image.png](attachment:image.png)
#
# Let us understand it in Simple Linear Regression first.
#
# When we fit a straight line through the data, we get two parameter i.e the intercept(β0) and the slope(β1).
#
# ![image-2.png](attachment:image-2.png)
#
# Now β0 is not much importance right now, but there are few aspected around β1 which needs to  be checked and verified. Suppose we have a dataset for which the scatter plot looks the following:
#
# ![image-3.png](attachment:image-3.png)
# when we run a liner regression on this data set in python, Python will fit a line on the data which looks like the following:
#
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# # Q13. How would you decide the importance of variables for the multivariate regression?
#
# Based on the correlation of the variable with target feature. we can decide the importantnce of the variable.

# %% [markdown]
# # Q14. How do you interpret the coefficient of a linear regression model?
#
# The coefficient represents the
# change in the dependent
# variable for a one-unit change in
# the corresponding independent
# variable, holding all other
# variables constant.

# %% [markdown]
# # Q15. What is the purpose of the residual plot in linear regression?
#
# The residual plot helps us assess
# the goodness of fit of the linear
# regression model by examining
# the distribution and patterns of
# the residuals. It helps to identify
# potential issues such as
# heteroscedasticity or non-linearity.

# %% [markdown]
# # Q16. How do you handle multicollinearity in linear regression?
#
# Multicollinearity occurs when
# independent variables are highly
# correlated. To handle it, one can
# remove one of the correlated
# variables, perform dimensionality
# reduction techniques like principal
# component analysis (PCA), or
# use regularization techniques like
# ridge regression or LASSO
# regression

# %% [markdown]
# # Q17.  What are the assumptions of the error term in linear regression?
# The assumptions of the error
# term include zero mean, constant
# variance, independence, and
# normal distribution

# %% [markdown]
# # Q18. What are some techniques to improve the performance of a linear regression model?
#
# Techniques to improve model
# performance include feature
# engineering, addressing outliers
# and influential points,
# transforming variables, applying
# regularization techniques, and
# considering interactions between
# variables

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Regularization 5 * - Mohd Monish</p>

# %% [raw]
# Q1. What is regularization and why is it used in machine learning?
# Q2. What is the difference between L1 and L2 ?
# Q3. Explain the concept of ridge regression and its role in regularization.
# Q4. What is the elastic net regularization and how does it combine L1 and L2 penalties?

# %% [markdown]
# # Q1. What is regularization and why is it used in machine learning?
#
# Regularization is a technique used in machine learning to prevent overfitting and improve the generalization ability of models. It involves adding a penalty term to the loss function during the training process, which helps control the complexity of the model. By adding this penalty, regularization discourages the model from fitting noise and random fluctuations in the training data.
#
# The goal of regularization is to find the right balance between fitting the training data well and avoiding overfitting. It encourages the model to capture the underlying patterns in the data while avoiding excessive complexity.
#
# Regularization Techniques:
#
# 1- L1 regularization (Lasso)
#
# 2- L2 regularization (Ridge).
#
# 3- Elatic Net
# ![image-2.png](attachment:image-2.png)
#
#
# Ridge, Lasso, and Elastic Net are three popular regularization techniques used in machine learning to address overfitting and improve the performance of models.

# %% [markdown]
# # 🎯 𝐇𝐞𝐫𝐞 𝐚𝐫𝐞 𝐬𝐨𝐦𝐞 𝐤𝐞𝐲 𝐩𝐨𝐢𝐧𝐭𝐬 𝐚𝐛𝐨𝐮𝐭 𝐫𝐞𝐠𝐮𝐥𝐚𝐫𝐢𝐳𝐚𝐭𝐢𝐨𝐧:-
#
# 1️⃣ 𝐔𝐬𝐞𝐬 𝐚𝐧𝐝 𝐈𝐦𝐩𝐨𝐫𝐭𝐚𝐧𝐜𝐞: Regularization prevents overfitting, enhances generalization, and promotes better feature selection. It's an invaluable tool to achieve accurate and robust models.
#
# 2️⃣ 𝐓𝐲𝐩𝐞𝐬 𝐨𝐟 𝐑𝐞𝐠𝐮𝐥𝐚𝐫𝐢𝐳𝐚𝐭𝐢𝐨𝐧: L1 (Lasso), L2 (Ridge), and Elastic Net regularization each bring unique strengths. L1 encourages feature selection, L2 discourages extreme parameter values, while Elastic Net strikes a balance between both.
#
# 3️⃣ 𝐖𝐡𝐞𝐧 𝐭𝐨 𝐔𝐬𝐞 𝐑𝐞𝐠𝐮𝐥𝐚𝐫𝐢𝐳𝐚𝐭𝐢𝐨𝐧: Regularization is ideal when the training data is limited, there are many features, or overfitting is observed. It's widely applicable in linear regression, logistic regression, neural networks, and support vector machines.

# %% [markdown]
# # 1- Ridge Regularization:
#
# Ridge regularization, also known as L2 regularization, adds the sum of squared coefficients to the loss function as penalty.
#
# Ridge regression, also known as L2 regularization, is another type of linear regression that uses a penalty term equal to the square of the magnitude of the coefficients. Instead of shrinking the coefficients to zero, this penalty term helps to shrink the coefficients of less important features towards zero, but it doesn't make them exactly zero. Ridge Regression is useful to handle multicollinearity problems by reducing the variance of the coefficients.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 2- Lasso Regularization:
#
# Lasso regularization, also known as L1 regularization, adds the sum of absolute values of coefficients to the loss function.
#
# Lasso (Least Absolute Shrinkage and Selection Operator) regression also known as L1 regularization, adds a penalty term to the cost function equal to the absolute value of the magnitude of the coefficients. Lasso Regression is useful to select important features of a dataset, it will shrink the less important feature's coefficient to zero and it's generally used where the number of features is high.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Can you explain the concept of Elastic Net regression? How does it differ from Ridge and Lasso regression?.⭐⭐
#
# - Elastic Net Regularization (L1+L2):
#
# Elastic Net Regularization  is a linear regression model that combines the properties of both Ridge and Lasso regression. Like Ridge, it adds a L2 regularization term to the cost function to prevent overfitting. Like Lasso, it adds a L1 regularization term to the cost function to perform feature selection. The trade-off between the L1 and L2 regularization terms is controlled by a parameter, alpha, that ranges from 0 to 1. When alpha = 0, the model becomes a Ridge regression, and when alpha = 1, it becomes a Lasso regression.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Q2. What is the difference between L1 and L2 ? 10⭐
#
# Both Lasso and Ridge regression are types of linear regression, but they have different approaches to solving the problem of overfitting, which occurs when a model is too complex and captures the noise in the data as well as the underlying relationship.
#
# Lasso (Least Absolute Shrinkage and Selection Operator) regression also known as L1 regularization, adds a penalty term to the cost function equal to the absolute value of the magnitude of the coefficients. Lasso Regression is useful to select important features of a dataset, it will shrink the less important feature's coefficient to zero and it's generally used where the number of features is high.
#
# Ridge regression, also known as L2 regularization, is another type of linear regression that uses a penalty term equal to the square of the magnitude of the coefficients. Instead of shrinking the coefficients to zero, this penalty term helps to shrink the coefficients of less important features towards zero, but it doesn't make them exactly zero. Ridge Regression is useful to handle multicollinearity problems by reducing the variance of the coefficients.

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Logistic Regression 5 * - Mohd Monish</p>

# %% [raw]
# Q1. What is Logistic Regression?
# Q2. Difference between logistic and linear regression?

# %% [markdown]
# # Q1. What is Logistic Regression?
#
# ● Logistics Regression is a statistics modeling technique that is used for Predict Categorical outcomes based on input variable.
#
# ● Unlike linear regression, which is used for continuous outcomes, Logistics Regression deals with Binary outcomes(e.g yes/no, success/failure) or Multiclass outcomes(e.g low/medium/high). It estimate the Probability of an event Occuring by fitting a logistic function to the input data.
#
#                                          Another Defintion
#
# ● Logistics Regression is one of the most popular Machine learning algorithm, that belongs to the supervised learning technique. It is used for Predicting the Categorical dependent variable using a given set of independent variables.
#
# ● Logistics Regression Predicts the output of a Categorical dependent variable. Therefore the outcome must be a Categorical or Discrete value. It can be either Yes or No, 0 or 1,True or False, etc, But instead of giving the exact value 0 and 1. it gives the proababilistic values which lie between 0 and 1.
#
# ● Logistics Regression is much similar to the Linear Regression except that how they are used. Linear Regression is used for solving Regression Problems, Where as Logistics Regression is Used for solving Classification Problems
#
# ● In Logistics Regression, instead of fitting a regression line, we fit av "S" shaped logistic function, which predict two maximum values(0 or 1).

# %% [markdown]
# # Logistic Function (Sigmoid Function)
# A logistic function or logistic curve is a common S-shaped curve (sigmoid curve) with
# equation.
# ![image.png](attachment:image.png)
# f(x) = output of the function
#
# L = the curve's maximum value
#
# k = logistic growth rate or steepness of the curve
#
# x0 = the x value of the sigmoid midpoint
#
# x = real number
#
# • The sigmoid function is a mathematical function used to map predicted values to
# probabilities.
#
# • It maps any real value into another value within a range of 0 and 1.
#
# • The value of the logistic regression must be between 0 and 1, which cannot go beyond this limit, so it forms a curve like the "S" form
#
# • The S-form curve is called the Sigmoid function or the logistic function.
#
# • In logistic regression, we use the concept of the threshold value, which defines the
# probability of either 0 or 1.
#
# • Values above the threshold value tend to 1 & Value below the threshold values tends to 0.
#
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Q2. Difference between logistic and linear regression?
#
# ● Linear Regression is used the Continous dependent variable using a give set of independent variables, While/Where as Logistics Regression is Used the Categorical dependent variable using a give set of independent variables.
#
# ● Linear Regression is used for solving Regression Problems, While/Where as Logistics Regression is Used for solving Classification Problems.
#
# ● Linear Regression Output Continous Value (Price, age etc), While/Where as Logistics Regression Output Categorical Value (0/1, Yes/No etc).
#
# ● Linear Regression Relationship between dependent variable and Independent variable must be linear, While/Where as Logistics Regression Relationship between dependent variable and Independent variable is not required.
#
# ● Linear Regression Independent variable can be Collinear, While/Where as Logistics Regression Independent variable can-not be Collinear.

# %% [markdown]
# # Type of Logistic Regression:
#
# Based on the categories, Logistic Regression can be classified into three types:
#
# 1. Binomial: In binomial Logistic regression, there can be only two possible types of the
# dependent variables, such as 0 or 1, Pass or Fail, etc.
#
# 2. Multinomial: In multinomial Logistic regression, there can be 3 or more possible unordered
# types of the dependent variable, such as "cat", "dogs", or "sheep"
#
# 3. Ordinal: In ordinal Logistic regression, there can be 3 or more possible ordered types of
# dependent variables, such as "low", "Medium", or "High"

# %% [markdown]
# # How Does Logistic Regression Work?
#
# Logistic regression works by building a model that predicts the probability of the outcome
# being a certain value (e.g. success or failure). This probability is then used to make a
# prediction about the outcome. The model is built by finding the best parameters (also known
# as coefficients) that minimize the error between the predicted probabilities and the actual
# outcomes.

# %% [markdown]
# # Implementing Logistic Regression in Python:
#
# The following code demonstrates how to implement logistic regression in Python using the
# scikit-learn library:
#
# from sklearn.linear_model import LogisticRegression
# from sklearn.model_selection import train_test_split
# # Load data
# X = ...
# y = ...
# # Split data into training and test sets
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# # Create logistic regression model
# model = LogisticRegression()
# # Fit model to training data
# model.fit(X_train, y_train)
# # Make predictions on test data
# y_pred = model.predict(X_test)
# # Evaluate model performance
# accuracy = model.score(X_test, y_test)
# print('Accuracy:', accuracy)
